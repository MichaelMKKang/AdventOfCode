# %%
import re
with open('Day17 input.txt') as f:
    lines = f.readlines()
lines = [x.strip() for x in lines]
line = lines[0][13:]
print(line)
x_range = re.search('(?<=x=).*(?=, )',line)[0]
x_range = [int(re.search('.*(?=\.\.)',x_range)[0]), int(re.search('(?<=\.\.).*',x_range)[0])]
print(x_range)
y_range = re.search('(?<=, y=).*',line)[0]
y_range = [int(re.search('.*(?=\.\.)',y_range)[0]), int(re.search('(?<=\.\.).*',y_range)[0])]
print(y_range)
# Out:
# x=175..227, y=-134..-79
# [175, 227]
# [-134, -79]

# %%
#pos is (x,y), vel is (x_vel,y_vel)
# outputs new step,new vel
def step(x,y,x_vel,y_vel):
    new_x_pos = x + x_vel
    new_y_pos = y + y_vel
    y_vel -= 1
    if x_vel > 0:
        x_vel -= 1
    elif x_vel < 0:
        x_vel += 1
    else:
        pass
    return new_x_pos,new_y_pos,x_vel,y_vel

# %%
#returns 0 if winning shot, -1 if under, 1 if over, 2 if goes through
def try_shot(x,y,x_vel,y_vel):
    initial_y_vel = y_vel
    max_height = 0
    while x_vel != 0 or y >= y_range[0]:
        #step
        x,y,x_vel,y_vel = step(x,y,x_vel,y_vel)
        if y > max_height:
            max_height = y
        #print(x,y,x_vel,y_vel)
        #check for win
        if (x_range[0] <= x <= x_range[1]) and (y_range[0] <= y <= y_range[1]):
            print('y velocity ',initial_y_vel, ' has a max height of: ',max_height)
            return 0
        #every shot eventually gets to x_vel==0, but mercykill
        #if y_vel < 0 and y < y_range[0]:
        #    return -1
    #now x_vel == 0 and y_pos is under the box
    if x < x_range[0]:
        return -1
    elif x > x_range[1]:
        return 1
    else:
        return 2

# %%
#Part 1
max_height = 0
winning_y_vels = []
x,y=0,0
start_x_vel = 0
for start_y_vel in range(-10,400):    #for each value of y_vel
    x_vel,y_vel = start_x_vel,start_y_vel

    success = False
    max_height = 0
    attempted_x_vels = []
    while 1:
        attempted_x_vels.append(x_vel)
        x_result = try_shot(x,y,x_vel,y_vel)
        if x_result == 0:
            #print(start_y_vel,':  ',x_vel,y_vel,'successfully hits')
            success = True
            break
        #no situation where it doesn't go through for starting y_vel for any x
        elif x_result == 2:
            print(start_y_vel,x_vel,':  ',y_vel,'goes through')
            break
        else:
            x_vel += -x_result
            if x_vel in attempted_x_vels:
                #print(start_y_vel,':  ',y_vel,'no solution')
                break
    
    if success:
        #print(start_y_vel,'successfully hits')
        winning_y_vels.append(start_y_vel)
    else:
        #if len(winning_y_vels)>0:
        #    break
        #print(start_y_vel, 'doesn\'t hit')
        pass

print(max(winning_y_vels))
# Out:
# -10 19 :   -10 goes through
# -9 19 :   -9 goes through
# -8 19 :   -8 goes through
# -7 19 :   -7 goes through
# -6 19 :   -6 goes through
# -5 19 :   -5 goes through
# -4 19 :   -4 goes through
# y velocity  -3  has a max height of:  0
# y velocity  -2  has a max height of:  0
# y velocity  -1  has a max height of:  0
# y velocity  0  has a max height of:  0
# y velocity  1  has a max height of:  1
# y velocity  2  has a max height of:  3
# y velocity  3  has a max height of:  6
# y velocity  4  has a max height of:  10
# y velocity  5  has a max height of:  15
# y velocity  6  has a max height of:  21
# y velocity  7  has a max height of:  28
# y velocity  100  has a max height of:  5050
# y velocity  101  has a max height of:  5151
# y velocity  102  has a max height of:  5253
# y velocity  103  has a max height of:  5356
# y velocity  104  has a max height of:  5460
# y velocity  105  has a max height of:  5565
# y velocity  106  has a max height of:  5671
# y velocity  107  has a max height of:  5778
# y velocity  108  has a max height of:  5886
# y velocity  109  has a max height of:  5995
# y velocity  110  has a max height of:  6105
# y velocity  111  has a max height of:  6216
# y velocity  112  has a max height of:  6328
# y velocity  113  has a max height of:  6441
# y velocity  114  has a max height of:  6555
# y velocity  115  has a max height of:  6670
# y velocity  116  has a max height of:  6786
# y velocity  117  has a max height of:  6903
# y velocity  118  has a max height of:  7021
# y velocity  119  has a max height of:  7140
# y velocity  120  has a max height of:  7260
# y velocity  121  has a max height of:  7381
# y velocity  122  has a max height of:  7503
# y velocity  123  has a max height of:  7626
# y velocity  124  has a max height of:  7750
# y velocity  125  has a max height of:  7875
# y velocity  126  has a max height of:  8001
# y velocity  127  has a max height of:  8128
# y velocity  128  has a max height of:  8256
# y velocity  129  has a max height of:  8385
# y velocity  130  has a max height of:  8515
# y velocity  131  has a max height of:  8646
# y velocity  132  has a max height of:  8778
# y velocity  133  has a max height of:  8911
# 134 19 :   134 goes through
# 135 19 :   135 goes through
# 136 19 :   136 goes through
# 137 19 :   137 goes through
# 138 19 :   138 goes through
# 139 19 :   139 goes through
# 140 19 :   140 goes through
# 141 19 :   141 goes through
# 142 19 :   142 goes through
# 143 19 :   143 goes through
# 144 19 :   144 goes through
# 145 19 :   145 goes through
# 146 19 :   146 goes through
# 147 19 :   147 goes through
# 148 19 :   148 goes through
# 149 19 :   149 goes through
# 150 19 :   150 goes through
# 151 19 :   151 goes through
# 152 19 :   152 goes through
# 153 19 :   153 goes through
# 154 19 :   154 goes through
# 155 19 :   155 goes through
# 156 19 :   156 goes through
# 157 19 :   157 goes through
# 158 19 :   158 goes through
# 159 19 :   159 goes through
# 160 19 :   160 goes through
# 161 19 :   161 goes through
# 162 19 :   162 goes through
# 163 19 :   163 goes through
# 164 19 :   164 goes through
# 165 19 :   165 goes through
# 166 19 :   166 goes through
# 167 19 :   167 goes through
# 168 19 :   168 goes through
# 169 19 :   169 goes through
# 170 19 :   170 goes through
# 171 19 :   171 goes through
# 172 19 :   172 goes through
# 173 19 :   173 goes through
# 174 19 :   174 goes through
# 175 19 :   175 goes through
# 176 19 :   176 goes through
# 177 19 :   177 goes through
# 178 19 :   178 goes through
# 179 19 :   179 goes through
# 180 19 :   180 goes through
# 181 19 :   181 goes through
# 182 19 :   182 goes through
# 183 19 :   183 goes through
# 184 19 :   184 goes through
# 185 19 :   185 goes through
# 186 19 :   186 goes through
# 187 19 :   187 goes through
# 188 19 :   188 goes through
# 189 19 :   189 goes through
# 190 19 :   190 goes through
# 191 19 :   191 goes through
# 192 19 :   192 goes through
# 193 19 :   193 goes through
# 194 19 :   194 goes through
# 195 19 :   195 goes through
# 196 19 :   196 goes through
# 197 19 :   197 goes through
# 198 19 :   198 goes through
# 199 19 :   199 goes through
# 200 19 :   200 goes through
# 201 19 :   201 goes through
# 202 19 :   202 goes through
# 203 19 :   203 goes through
# 317 19 :   317 goes through
# 318 19 :   318 goes through
# 319 19 :   319 goes through
# 320 19 :   320 goes through
# 321 19 :   321 goes through
# 322 19 :   322 goes through
# 323 19 :   323 goes through
# 324 19 :   324 goes through
# 325 19 :   325 goes through
# 326 19 :   326 goes through
# 327 19 :   327 goes through
# 328 19 :   328 goes through
# 329 19 :   329 goes through
# 330 19 :   330 goes through
# 331 19 :   331 goes through
# 332 19 :   332 goes through
# 333 19 :   333 goes through
# 334 19 :   334 goes through
# 335 19 :   335 goes through
# 336 19 :   336 goes through
# 337 19 :   337 goes through
# 338 19 :   338 goes through
# 339 19 :   339 goes through
# 340 19 :   340 goes through
# 341 19 :   341 goes through
# 342 19 :   342 goes through
# 343 19 :   343 goes through
# 344 19 :   344 goes through
# 345 19 :   345 goes through
# 346 19 :   346 goes through
# 347 19 :   347 goes through
# 348 19 :   348 goes through
# 349 19 :   349 goes through
# 350 19 :   350 goes through
# 351 19 :   351 goes through
# 352 19 :   352 goes through
# 353 19 :   353 goes through
# 354 19 :   354 goes through
# 355 19 :   355 goes through
# 356 19 :   356 goes through
# 357 19 :   357 goes through
# 358 19 :   358 goes through
# 359 19 :   359 goes through
# 360 19 :   360 goes through
# 361 19 :   361 goes through
# 362 19 :   362 goes through
# 363 19 :   363 goes through
# 364 19 :   364 goes through
# 365 19 :   365 goes through
# 366 19 :   366 goes through
# 367 19 :   367 goes through
# 368 19 :   368 goes through
# 369 19 :   369 goes through
# 370 19 :   370 goes through
# 371 19 :   371 goes through
# 372 19 :   372 goes through
# 373 19 :   373 goes through
# 374 19 :   374 goes through
# 375 19 :   375 goes through
# 376 19 :   376 goes through
# 377 19 :   377 goes through
# 378 19 :   378 goes through
# 379 19 :   379 goes through
# 380 19 :   380 goes through
# 381 19 :   381 goes through
# 382 19 :   382 goes through
# 383 19 :   383 goes through
# 384 19 :   384 goes through
# 385 19 :   385 goes through
# 386 19 :   386 goes through
# 387 19 :   387 goes through
# 388 19 :   388 goes through
# 389 19 :   389 goes through
# 390 19 :   390 goes through
# 391 19 :   391 goes through
# 392 19 :   392 goes through
# 393 19 :   393 goes through
# 394 19 :   394 goes through
# 395 19 :   395 goes through
# 396 19 :   396 goes through
# 397 19 :   397 goes through
# 398 19 :   398 goes through
# 399 19 :   399 goes through
# 133

# %%
#returns 0 if winning shot, -1 if under, 1 if over, 2 if goes through
def try_shot_part2(x,y,x_vel,y_vel):
    initial_y_vel = y_vel
    max_height = 0
    while x_vel != 0 or y >= y_range[0]:
        #step
        x,y,x_vel,y_vel = step(x,y,x_vel,y_vel)
        if y > max_height:
            max_height = y
        #print(x,y,x_vel,y_vel)
        #check for win
        if (x_range[0] <= x <= x_range[1]) and (y_range[0] <= y <= y_range[1]):
            #print('y velocity ',initial_y_vel, ' has a max height of: ',max_height)
            return 0
        #every shot eventually gets to x_vel==0, but mercykill
        #if y_vel < 0 and y < y_range[0]:
        #    return -1
    #now x_vel == 0 and y_pos is under the box
    if x < x_range[0]:
        return -1
    elif x > x_range[1]:
        return 1
    else:
        return 2

# %%
#Part 2

direct_shot_counts = (x_range[1]-x_range[0]) * (y_range[1]-y_range[0])
print(direct_shot_counts)

max_height = 0
count = 0
winning_y_vels = []
x,y=0,0

for start_y_vel in range(-150,150):    #for each value of y_vel
    for start_x_vel in range(230):    #then just add by the # of direct shots
        x_vel,y_vel = start_x_vel,start_y_vel
        if try_shot_part2(x,y,x_vel,y_vel) == 0:
            count += 1
    print('start y velocity: ',start_y_vel, 'with cumulative count ',count)


print(count)
# Out:
# 2860
# start y velocity:  -150 with cumulative count  0
# start y velocity:  -149 with cumulative count  0
# start y velocity:  -148 with cumulative count  0
# start y velocity:  -147 with cumulative count  0
# start y velocity:  -146 with cumulative count  0
# start y velocity:  -145 with cumulative count  0
# start y velocity:  -144 with cumulative count  0
# start y velocity:  -143 with cumulative count  0
# start y velocity:  -142 with cumulative count  0
# start y velocity:  -141 with cumulative count  0
# start y velocity:  -140 with cumulative count  0
# start y velocity:  -139 with cumulative count  0
# start y velocity:  -138 with cumulative count  0
# start y velocity:  -137 with cumulative count  0
# start y velocity:  -136 with cumulative count  0
# start y velocity:  -135 with cumulative count  0
# start y velocity:  -134 with cumulative count  53
# start y velocity:  -133 with cumulative count  106
# start y velocity:  -132 with cumulative count  159
# start y velocity:  -131 with cumulative count  212
# start y velocity:  -130 with cumulative count  265
# start y velocity:  -129 with cumulative count  318
# start y velocity:  -128 with cumulative count  371
# start y velocity:  -127 with cumulative count  424
# start y velocity:  -126 with cumulative count  477
# start y velocity:  -125 with cumulative count  530
# start y velocity:  -124 with cumulative count  583
# start y velocity:  -123 with cumulative count  636
# start y velocity:  -122 with cumulative count  689
# start y velocity:  -121 with cumulative count  742
# start y velocity:  -120 with cumulative count  795
# start y velocity:  -119 with cumulative count  848
# start y velocity:  -118 with cumulative count  901
# start y velocity:  -117 with cumulative count  954
# start y velocity:  -116 with cumulative count  1007
# start y velocity:  -115 with cumulative count  1060
# start y velocity:  -114 with cumulative count  1113
# start y velocity:  -113 with cumulative count  1166
# start y velocity:  -112 with cumulative count  1219
# start y velocity:  -111 with cumulative count  1272
# start y velocity:  -110 with cumulative count  1325
# start y velocity:  -109 with cumulative count  1378
# start y velocity:  -108 with cumulative count  1431
# start y velocity:  -107 with cumulative count  1484
# start y velocity:  -106 with cumulative count  1537
# start y velocity:  -105 with cumulative count  1590
# start y velocity:  -104 with cumulative count  1643
# start y velocity:  -103 with cumulative count  1696
# start y velocity:  -102 with cumulative count  1749
# start y velocity:  -101 with cumulative count  1802
# start y velocity:  -100 with cumulative count  1855
# start y velocity:  -99 with cumulative count  1908
# start y velocity:  -98 with cumulative count  1961
# start y velocity:  -97 with cumulative count  2014
# start y velocity:  -96 with cumulative count  2067
# start y velocity:  -95 with cumulative count  2120
# start y velocity:  -94 with cumulative count  2173
# start y velocity:  -93 with cumulative count  2226
# start y velocity:  -92 with cumulative count  2279
# start y velocity:  -91 with cumulative count  2332
# start y velocity:  -90 with cumulative count  2385
# start y velocity:  -89 with cumulative count  2438
# start y velocity:  -88 with cumulative count  2491
# start y velocity:  -87 with cumulative count  2544
# start y velocity:  -86 with cumulative count  2597
# start y velocity:  -85 with cumulative count  2650
# start y velocity:  -84 with cumulative count  2703
# start y velocity:  -83 with cumulative count  2756
# start y velocity:  -82 with cumulative count  2809
# start y velocity:  -81 with cumulative count  2862
# start y velocity:  -80 with cumulative count  2915
# start y velocity:  -79 with cumulative count  2968
# start y velocity:  -78 with cumulative count  2968
# start y velocity:  -77 with cumulative count  2968
# start y velocity:  -76 with cumulative count  2968
# start y velocity:  -75 with cumulative count  2968
# start y velocity:  -74 with cumulative count  2968
# start y velocity:  -73 with cumulative count  2968
# start y velocity:  -72 with cumulative count  2968
# start y velocity:  -71 with cumulative count  2968
# start y velocity:  -70 with cumulative count  2968
# start y velocity:  -69 with cumulative count  2968
# start y velocity:  -68 with cumulative count  2968
# start y velocity:  -67 with cumulative count  2968
# start y velocity:  -66 with cumulative count  2995
# start y velocity:  -65 with cumulative count  3022
# start y velocity:  -64 with cumulative count  3049
# start y velocity:  -63 with cumulative count  3076
# start y velocity:  -62 with cumulative count  3103
# start y velocity:  -61 with cumulative count  3130
# start y velocity:  -60 with cumulative count  3157
# start y velocity:  -59 with cumulative count  3184
# start y velocity:  -58 with cumulative count  3211
# start y velocity:  -57 with cumulative count  3238
# start y velocity:  -56 with cumulative count  3265
# start y velocity:  -55 with cumulative count  3292
# start y velocity:  -54 with cumulative count  3319
# start y velocity:  -53 with cumulative count  3346
# start y velocity:  -52 with cumulative count  3373
# start y velocity:  -51 with cumulative count  3400
# start y velocity:  -50 with cumulative count  3427
# start y velocity:  -49 with cumulative count  3454
# start y velocity:  -48 with cumulative count  3481
# start y velocity:  -47 with cumulative count  3508
# start y velocity:  -46 with cumulative count  3535
# start y velocity:  -45 with cumulative count  3562
# start y velocity:  -44 with cumulative count  3589
# start y velocity:  -43 with cumulative count  3633
# start y velocity:  -42 with cumulative count  3677
# start y velocity:  -41 with cumulative count  3721
# start y velocity:  -40 with cumulative count  3765
# start y velocity:  -39 with cumulative count  3809
# start y velocity:  -38 with cumulative count  3826
# start y velocity:  -37 with cumulative count  3843
# start y velocity:  -36 with cumulative count  3860
# start y velocity:  -35 with cumulative count  3877
# start y velocity:  -34 with cumulative count  3894
# start y velocity:  -33 with cumulative count  3911
# start y velocity:  -32 with cumulative count  3941
# start y velocity:  -31 with cumulative count  3971
# start y velocity:  -30 with cumulative count  4001
# start y velocity:  -29 with cumulative count  4031
# start y velocity:  -28 with cumulative count  4061
# start y velocity:  -27 with cumulative count  4091
# start y velocity:  -26 with cumulative count  4121
# start y velocity:  -25 with cumulative count  4134
# start y velocity:  -24 with cumulative count  4156
# start y velocity:  -23 with cumulative count  4178
# start y velocity:  -22 with cumulative count  4200
# start y velocity:  -21 with cumulative count  4222
# start y velocity:  -20 with cumulative count  4244
# start y velocity:  -19 with cumulative count  4271
# start y velocity:  -18 with cumulative count  4287
# start y velocity:  -17 with cumulative count  4303
# start y velocity:  -16 with cumulative count  4323
# start y velocity:  -15 with cumulative count  4343
# start y velocity:  -14 with cumulative count  4363
# start y velocity:  -13 with cumulative count  4378
# start y velocity:  -12 with cumulative count  4393
# start y velocity:  -11 with cumulative count  4408
# start y velocity:  -10 with cumulative count  4420
# start y velocity:  -9 with cumulative count  4432
# start y velocity:  -8 with cumulative count  4442
# start y velocity:  -7 with cumulative count  4453
# start y velocity:  -6 with cumulative count  4462
# start y velocity:  -5 with cumulative count  4471
# start y velocity:  -4 with cumulative count  4479
# start y velocity:  -3 with cumulative count  4486
# start y velocity:  -2 with cumulative count  4492
# start y velocity:  -1 with cumulative count  4497
# start y velocity:  0 with cumulative count  4501
# start y velocity:  1 with cumulative count  4505
# start y velocity:  2 with cumulative count  4508
# start y velocity:  3 with cumulative count  4511
# start y velocity:  4 with cumulative count  4514
# start y velocity:  5 with cumulative count  4516
# start y velocity:  6 with cumulative count  4518
# start y velocity:  7 with cumulative count  4520
# start y velocity:  8 with cumulative count  4522
# start y velocity:  9 with cumulative count  4524
# start y velocity:  10 with cumulative count  4526
# start y velocity:  11 with cumulative count  4528
# start y velocity:  12 with cumulative count  4530
# start y velocity:  13 with cumulative count  4532
# start y velocity:  14 with cumulative count  4534
# start y velocity:  15 with cumulative count  4536
# start y velocity:  16 with cumulative count  4538
# start y velocity:  17 with cumulative count  4540
# start y velocity:  18 with cumulative count  4542
# start y velocity:  19 with cumulative count  4544
# start y velocity:  20 with cumulative count  4546
# start y velocity:  21 with cumulative count  4548
# start y velocity:  22 with cumulative count  4550
# start y velocity:  23 with cumulative count  4552
# start y velocity:  24 with cumulative count  4554
# start y velocity:  25 with cumulative count  4556
# start y velocity:  26 with cumulative count  4558
# start y velocity:  27 with cumulative count  4560
# start y velocity:  28 with cumulative count  4562
# start y velocity:  29 with cumulative count  4564
# start y velocity:  30 with cumulative count  4566
# start y velocity:  31 with cumulative count  4568
# start y velocity:  32 with cumulative count  4570
# start y velocity:  33 with cumulative count  4572
# start y velocity:  34 with cumulative count  4574
# start y velocity:  35 with cumulative count  4576
# start y velocity:  36 with cumulative count  4578
# start y velocity:  37 with cumulative count  4580
# start y velocity:  38 with cumulative count  4582
# start y velocity:  39 with cumulative count  4584
# start y velocity:  40 with cumulative count  4586
# start y velocity:  41 with cumulative count  4588
# start y velocity:  42 with cumulative count  4590
# start y velocity:  43 with cumulative count  4592
# start y velocity:  44 with cumulative count  4594
# start y velocity:  45 with cumulative count  4596
# start y velocity:  46 with cumulative count  4598
# start y velocity:  47 with cumulative count  4600
# start y velocity:  48 with cumulative count  4602
# start y velocity:  49 with cumulative count  4604
# start y velocity:  50 with cumulative count  4606
# start y velocity:  51 with cumulative count  4608
# start y velocity:  52 with cumulative count  4610
# start y velocity:  53 with cumulative count  4612
# start y velocity:  54 with cumulative count  4614
# start y velocity:  55 with cumulative count  4616
# start y velocity:  56 with cumulative count  4618
# start y velocity:  57 with cumulative count  4620
# start y velocity:  58 with cumulative count  4622
# start y velocity:  59 with cumulative count  4624
# start y velocity:  60 with cumulative count  4626
# start y velocity:  61 with cumulative count  4628
# start y velocity:  62 with cumulative count  4630
# start y velocity:  63 with cumulative count  4632
# start y velocity:  64 with cumulative count  4634
# start y velocity:  65 with cumulative count  4636
# start y velocity:  66 with cumulative count  4636
# start y velocity:  67 with cumulative count  4636
# start y velocity:  68 with cumulative count  4636
# start y velocity:  69 with cumulative count  4636
# start y velocity:  70 with cumulative count  4636
# start y velocity:  71 with cumulative count  4636
# start y velocity:  72 with cumulative count  4636
# start y velocity:  73 with cumulative count  4636
# start y velocity:  74 with cumulative count  4636
# start y velocity:  75 with cumulative count  4636
# start y velocity:  76 with cumulative count  4636
# start y velocity:  77 with cumulative count  4636
# start y velocity:  78 with cumulative count  4638
# start y velocity:  79 with cumulative count  4640
# start y velocity:  80 with cumulative count  4642
# start y velocity:  81 with cumulative count  4644
# start y velocity:  82 with cumulative count  4646
# start y velocity:  83 with cumulative count  4648
# start y velocity:  84 with cumulative count  4650
# start y velocity:  85 with cumulative count  4652
# start y velocity:  86 with cumulative count  4654
# start y velocity:  87 with cumulative count  4656
# start y velocity:  88 with cumulative count  4658
# start y velocity:  89 with cumulative count  4660
# start y velocity:  90 with cumulative count  4662
# start y velocity:  91 with cumulative count  4664
# start y velocity:  92 with cumulative count  4666
# start y velocity:  93 with cumulative count  4668
# start y velocity:  94 with cumulative count  4670
# start y velocity:  95 with cumulative count  4672
# start y velocity:  96 with cumulative count  4674
# start y velocity:  97 with cumulative count  4676
# start y velocity:  98 with cumulative count  4678
# start y velocity:  99 with cumulative count  4680
# start y velocity:  100 with cumulative count  4682
# start y velocity:  101 with cumulative count  4684
# start y velocity:  102 with cumulative count  4686
# start y velocity:  103 with cumulative count  4688
# start y velocity:  104 with cumulative count  4690
# start y velocity:  105 with cumulative count  4692
# start y velocity:  106 with cumulative count  4694
# start y velocity:  107 with cumulative count  4696
# start y velocity:  108 with cumulative count  4698
# start y velocity:  109 with cumulative count  4700
# start y velocity:  110 with cumulative count  4702
# start y velocity:  111 with cumulative count  4704
# start y velocity:  112 with cumulative count  4706
# start y velocity:  113 with cumulative count  4708
# start y velocity:  114 with cumulative count  4710
# start y velocity:  115 with cumulative count  4712
# start y velocity:  116 with cumulative count  4714
# start y velocity:  117 with cumulative count  4716
# start y velocity:  118 with cumulative count  4718
# start y velocity:  119 with cumulative count  4720
# start y velocity:  120 with cumulative count  4722
# start y velocity:  121 with cumulative count  4724
# start y velocity:  122 with cumulative count  4726
# start y velocity:  123 with cumulative count  4728
# start y velocity:  124 with cumulative count  4730
# start y velocity:  125 with cumulative count  4732
# start y velocity:  126 with cumulative count  4734
# start y velocity:  127 with cumulative count  4736
# start y velocity:  128 with cumulative count  4738
# start y velocity:  129 with cumulative count  4740
# start y velocity:  130 with cumulative count  4742
# start y velocity:  131 with cumulative count  4744
# start y velocity:  132 with cumulative count  4746
# start y velocity:  133 with cumulative count  4748
# start y velocity:  134 with cumulative count  4748
# start y velocity:  135 with cumulative count  4748
# start y velocity:  136 with cumulative count  4748
# start y velocity:  137 with cumulative count  4748
# start y velocity:  138 with cumulative count  4748
# start y velocity:  139 with cumulative count  4748
# start y velocity:  140 with cumulative count  4748
# start y velocity:  141 with cumulative count  4748
# start y velocity:  142 with cumulative count  4748
# start y velocity:  143 with cumulative count  4748
# start y velocity:  144 with cumulative count  4748
# start y velocity:  145 with cumulative count  4748
# start y velocity:  146 with cumulative count  4748
# start y velocity:  147 with cumulative count  4748
# start y velocity:  148 with cumulative count  4748
# start y velocity:  149 with cumulative count  4748
# 4748
